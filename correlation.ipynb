# %%
import datetime
import csv
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import numpy as np
import ipyvolume as ipv

# %%
data = pd.read_csv('istherecorrelation.csv', delimiter = ";" , decimal=',')
#data = data.apply(lambda x: x.replace(',','.'))
data
# Out:
#     Year  WO [x1000]  NL Beer consumption [x1000 hectoliter]
# 0   2006       205.9                                   11402
# 1   2007       208.6                                   11492
# 2   2008       212.7                                   11450
# 3   2009       220.5                                   11502
# 4   2010       233.2                                   11474
# 5   2011       242.4                                   11480
# 6   2012       245.4                                   11452
# 7   2013       241.4                                   11484
# 8   2014       250.2                                   11555
# 9   2015       255.7                                   11601
# 10  2016       261.2                                   11731
# 11  2017       267.9                                   11862
# 12  2018       280.1                                   12048

# %%
x = data['Year']
y = data['WO [x1000]']
z = data['NL Beer consumption [x1000 hectoliter]']

# %%
width = .25
fig = plt.figure(figsize=(7,7), dpi = 300)


data['WO [x1000]'].plot(kind='bar', width = width, color = 'blue', legend = True, label = 'WO [x1000]')
data['NL Beer consumption [x1000 hectoliter]'].plot(secondary_y=True, color = 'red' , label = 'NL Beer consumption [x1000 hectoliter]', ylim = (200,300))


ax = plt.gca()
ax.set_xticklabels(data['Year'], rotation=45, ha='right')

handles, labels = ax.get_legend_handles_labels()
plt.legend(handles, labels, loc='upper left')
fig = plt.figure(figsize=(1,1))

plt.show()
#fig.savefig(dpi = 300, format = 'png', fname = 'correlation.png')
