# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

mpl.rcParams['figure.dpi'] = 300

df = pd.read_csv('istherecorrelation.csv', delimiter=';')

Year = df['Year']
WO = df['WO [x1000]']
Beer = df['NL Beer consumption [x1000 hectoliter]']

print(df)
# Out:
#     Year WO [x1000]  NL Beer consumption [x1000 hectoliter]
# 0   2006      205,9                                   11402
# 1   2007      208,6                                   11492
# 2   2008      212,7                                   11450
# 3   2009      220,5                                   11502
# 4   2010      233,2                                   11474
# 5   2011      242,4                                   11480
# 6   2012      245,4                                   11452
# 7   2013      241,4                                   11484
# 8   2014      250,2                                   11555
# 9   2015      255,7                                   11601
# 10  2016      261,2                                   11731
# 11  2017      267,9                                   11862
# 12  2018      280,1                                   12048

# %%
plt.subplot(1,2,1)
plt.plot(Year, WO, 'r')
plt.title("WO [x1000]")

plt.subplot(1,2,2)
plt.plot(Year, Beer, 'b')
plt.title("NL Beer consumption [x1000 hectoliter]")

plt.tight_layout(pad=3.0)

# %% [markdown]
# *Figure 1. The X-axes indicate years, while the Y-axes indicate values for WO / beer consumption in the Netherlands. There appears to be a positive correlation between beer consumption and WO.*
